# %%
class Customer:
    def _init_(self, name, age):
        self.name = name
        self.age = age

    def get_name(self):
        return self.name

    
    def set_name(self, name):
        self.name = name

    
    def get_age(self):
        return self.age

    
    def set_age(self, age):
        self.age = age


class MainBikeRental:
    def _init_(self):
        self.bikes = 0  
        self.rentals = []  

    
    def get_bikes(self):
        return self.bikes

    
    def set_bikes(self, number):
        self.bikes = number

    
    def get_rentals(self):
        return self.rentals

    
    def set_rentals(self, rentals):
        self.rentals = rentals

    def request_Bike(self, customer, number_of_bikes):
        if customer.get_age() < 6:
            print("Customer must be over 6 years old.")
            return
        if number_of_bikes <= self.bikes:
            self.bikes -= number_of_bikes
            self.rentals.append((customer.get_name(), number_of_bikes))
            print(f"Requested {number_of_bikes} bike(s) rented.")
        else:
            print("Wait 10 mins.")

    def returnBike(self, rental_time, num_of_bikes):
        total_cost = rental_time * 40
        self.bikes += num_of_bikes
        print(f"Bikes returned. Total cost: ${total_cost}.")

    def addBike(self, number_of_bikes):
        self.bikes += number_of_bikes
        print(f"Added {number_of_bikes} bike(s) to stock.")

    def totalCost(self):
        return self.bikes * 40

class Bike():
    def _init__(self,name,price):
        self.name=name
        self.price=price

    def get_name(self):
        return self.name

    
    def set_name(self, name):
        self.name = name

    def get_price(self):
        return get_price

    def set_price(self , price):
        self.price= price

class Bike:
    def __init__(self, maxspeed=0):
        self._maxspeed = maxspeed

    
    def get_maxspeed(self):
        return self._maxspeed

    
    def set_maxspeed(self, speed):
        self._maxspeed = speed


class ElectricBike(Bike):
    def __init__(self, maxspeed=0):
        super().__init__(maxspeed) 

    
    def get_maxspeed(self):
        return super().get_maxspeed()

    
    def set_maxspeed(self, speed):
        super().set_maxspeed(speed)


class NormalBike(Bike):
    def __init__(self, maxspeed=0):
        super().__init__(maxspeed)  

    
    def get_maxspeed(self):
        return super().get_maxspeed()

    def set_maxspeed(self, speed):
        super().set_maxspeed(speed)
